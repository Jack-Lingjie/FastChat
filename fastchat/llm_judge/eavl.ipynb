# %%
import pandas as pd
data1 = pd.read_csv('data/result/average.csv')
data2 = pd.read_csv('data/result/second_turn.csv')
# Out:
#                                                 model     score
# 0                                               gpt-4  8.990625
# 1                                       gpt-3.5-turbo  7.943750
# 2    ta_llama3_instruct_dpo_list_bsz1_trible_debug_v1  7.831250
# 3   ta_llama3_instruct_dpo_list_bsz1_trible_debug_v15  7.775000
# 4                   uf_llama3.1_instruct_dpo_2048_job  7.762500
# 5    uf_llama3.1_instruct_dpo_2048_trible_ta_rejected  7.750000
# 6   ta_llama3_instruct_dpo_list_bsz1_trible_debug_v11  7.743750
# 7   ta_llama3_instruct_dpo_list_bsz1_trible_debug_...  7.718750
# 8    ta_llama3_instruct_dpo_list_bsz1_trible_debug_v5  7.716981
# 9   ta_llama3_instruct_dpo_list_bsz1_trible_debug_...  7.712500
# 10  ta_llama3_instruct_dpo_list_bsz1_trible_debug_v10  7.712500
# 11   ta_llama3_instruct_dpo_list_bsz1_trible_debug_v9  7.693750
# 12               uf_llama3.1_instruct_dpo_2048_trible  7.687500
# 13   ta_llama3_instruct_dpo_list_bsz1_trible_debug_v4  7.670846
# ...

# %%
data_1 = data1["model"].values.tolist()
data_2 = data2["model"].values.tolist()

# %%
for item in data_1:
    if item not in data_2:
        print(item)
# Out:
# tulu_v2_8b_default_template_dpo_list_bsz1_trible_debug_v14
